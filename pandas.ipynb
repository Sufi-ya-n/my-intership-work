# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'Name': ['Alice','Bob'], 'Age': [25, 30]}

# %%
df = pd.DataFrame(data)

# %%
df.head() # First 5 rows
 # Summary statistics
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df[df['Age'] > 25] # Rows where Age &gt; 25
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender'] = ['F','M'] # Add new column
df.drop('Age', axis=1,)# Remove column
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.isnull()
# Out:
#     Name    Age  Gender
# 0  False  False   False
# 1  False  False   False

# %%
df.dropna()
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df.fillna(0)
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Gender'], dtype='str')

# %%
df.groupby('Gender') [ 'Age'].mean()
# Out:
# Gender
# F    25.0
# M    30.0
# Name: Age, dtype: float64

# %%
df1 = pd.DataFrame({'key': ['A', 'B'], 'Value1': [1, 2]})
df2 = pd.DataFrame({'key': ['A', 'B'], 'Value2': [3, 4]})

# %%
pd.merge(df1, df2, on='key')
df1.join(df2, lsuffix='_left', rsuffix='_right')
# Out:
#   key_left  Value1 key_right  Value2
# 0        A       1         A       3
# 1        B       2         B       4

# %%
#df = pd.read_csv('data.csv')
# df.to_csv('output.csv', index=False)

# %%
df.sort_values('Age')
df['Age'].apply(lambda x: x + 1)
df['Name'].unique()
df['Age'].value_counts()
# Out:
# Age
# 25    1
# 30    1
# Name: count, dtype: int64
